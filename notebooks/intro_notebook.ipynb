# %% [markdown]
# # Introduction to Jupyter Notebooks
# Welcome to your first notebook! Let's explore Python and GitHub integration.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load sample dataset
df = pd.read_csv('../data/simple_dataset.csv')
df.head()

# %%
# Simple plot
df.plot(kind='bar', x='Category', y='Value', legend=False)
plt.title('Sample Data Plot')
plt.show()
